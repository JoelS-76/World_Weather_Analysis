# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lngs = zip(lats, lngs)

#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
#Import the requests library
import requests
#Import API key
from config import api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

#Create an endpoint URL for a city
city_url = url + "&q=" + "city"

# %%
#Create an empty list to hold the weather data
city_data = []
#Print the beginning of the logging
print('beginning data retrieval    ')
print('----------------------------')

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in the list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the url, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
         # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
    except:
        print("City not found. Skipping...")
        pass
# Out:
# beginning data retrieval
# ----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | vao
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | sola
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | kurdzhinovo
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | port hardy
# Processing Record 11 of Set 1 | tres lagoas
# Processing Record 12 of Set 1 | sao filipe
# Processing Record 13 of Set 1 | bilibino
# Processing Record 14 of Set 1 | north bend
# Processing Record 15 of Set 1 | kouango
# Processing Record 16 of Set 1 | presque isle
# Processing Record 17 of Set 1 | alice springs
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | mirante do paranapanema
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | manokwari
# Processing Record 22 of Set 1 | dongargaon
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | neuquen
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | siva
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | batagay-alyta
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | sembakung
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | phalombe
# Processing Record 40 of Set 1 | touros
# Processing Record 41 of Set 1 | okhotsk
# Processing Record 42 of Set 1 | napier
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | miyako
# Processing Record 45 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 1 | honningsvag
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | rio grande
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | bilma
# Processing Record 1 of Set 2 | pachino
# Processing Record 2 of Set 2 | burica
# City not found. Skipping...
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | padang
# Processing Record 5 of Set 2 | alofi
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | praxedis guerrero
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | belaya gora
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | tazovskiy
# Processing Record 14 of Set 2 | yerbogachen
# Processing Record 15 of Set 2 | kitimat
# Processing Record 16 of Set 2 | fort nelson
# Processing Record 17 of Set 2 | iki-burul
# Processing Record 18 of Set 2 | kavaratti
# Processing Record 19 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 20 of Set 2 | sabang
# Processing Record 21 of Set 2 | henties bay
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | college
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | ust-nera
# Processing Record 29 of Set 2 | klaksvik
# Processing Record 30 of Set 2 | colares
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | kazachinskoye
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | ossora
# Processing Record 36 of Set 2 | fukue
# Processing Record 37 of Set 2 | kijaba
# City not found. Skipping...
# Processing Record 38 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 2 | poum
# Processing Record 40 of Set 2 | conceicao da barra
# Processing Record 41 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 2 | perth
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | cumberland
# Processing Record 45 of Set 2 | envira
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | bayburt
# Processing Record 48 of Set 2 | roald
# Processing Record 49 of Set 2 | bengkulu
# Processing Record 50 of Set 2 | gonaives
# Processing Record 1 of Set 3 | portland
# Processing Record 2 of Set 3 | palmer
# Processing Record 3 of Set 3 | bibiani
# Processing Record 4 of Set 3 | marshall
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | flinders
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | znamenskoye
# Processing Record 11 of Set 3 | itaituba
# Processing Record 12 of Set 3 | kailua
# Processing Record 13 of Set 3 | sao joao da barra
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | ixtapa
# Processing Record 17 of Set 3 | te anau
# Processing Record 18 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 3 | marneuli
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | constitucion
# Processing Record 22 of Set 3 | piacabucu
# Processing Record 23 of Set 3 | senador jose porfirio
# Processing Record 24 of Set 3 | termoli
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | nambucca heads
# Processing Record 27 of Set 3 | kaitangata
# Processing Record 28 of Set 3 | broome
# Processing Record 29 of Set 3 | sobolevo
# Processing Record 30 of Set 3 | carlos chagas
# Processing Record 31 of Set 3 | stornoway
# Processing Record 32 of Set 3 | nangomba
# Processing Record 33 of Set 3 | nabire
# Processing Record 34 of Set 3 | vilhena
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | jelgava
# Processing Record 38 of Set 3 | edd
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | komsomolskiy
# Processing Record 41 of Set 3 | cayenne
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | sayat
# Processing Record 44 of Set 3 | kapit
# Processing Record 45 of Set 3 | vardo
# Processing Record 46 of Set 3 | geraldton
# Processing Record 47 of Set 3 | cotonou
# Processing Record 48 of Set 3 | evensk
# Processing Record 49 of Set 3 | saldanha
# Processing Record 50 of Set 3 | louis trichardt
# Processing Record 1 of Set 4 | sitka
# Processing Record 2 of Set 4 | kofele
# Processing Record 3 of Set 4 | berdigestyakh
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | tomatlan
# Processing Record 10 of Set 4 | mao
# Processing Record 11 of Set 4 | sinnamary
# Processing Record 12 of Set 4 | ulaangom
# Processing Record 13 of Set 4 | vredendal
# Processing Record 14 of Set 4 | mana
# Processing Record 15 of Set 4 | lavrentiya
# Processing Record 16 of Set 4 | bluff
# Processing Record 17 of Set 4 | lebu
# Processing Record 18 of Set 4 | killybegs
# Processing Record 19 of Set 4 | shimoda
# Processing Record 20 of Set 4 | christchurch
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | nampula
# Processing Record 23 of Set 4 | sao felix do xingu
# Processing Record 24 of Set 4 | imbituba
# Processing Record 25 of Set 4 | tessalit
# Processing Record 26 of Set 4 | najran
# Processing Record 27 of Set 4 | iqaluit
# Processing Record 28 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | necochea
# Processing Record 31 of Set 4 | mombetsu
# Processing Record 32 of Set 4 | vila velha
# Processing Record 33 of Set 4 | bambous virieux
# Processing Record 34 of Set 4 | ndioum
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | asau
# Processing Record 38 of Set 4 | beringovskiy
# Processing Record 39 of Set 4 | tigil
# Processing Record 40 of Set 4 | san quintin
# Processing Record 41 of Set 4 | morondava
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | sao gabriel da cachoeira
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | mattru
# Processing Record 47 of Set 4 | never
# Processing Record 48 of Set 4 | tabas
# Processing Record 49 of Set 4 | puerto ayora
# Processing Record 50 of Set 4 | peniche
# Processing Record 1 of Set 5 | bayji
# Processing Record 2 of Set 5 | vrangel
# Processing Record 3 of Set 5 | hovd
# Processing Record 4 of Set 5 | baboua
# City not found. Skipping...
# Processing Record 5 of Set 5 | pacific grove
# Processing Record 6 of Set 5 | tura
# Processing Record 7 of Set 5 | seymchan
# Processing Record 8 of Set 5 | port hawkesbury
# Processing Record 9 of Set 5 | mount isa
# Processing Record 10 of Set 5 | suifenhe
# Processing Record 11 of Set 5 | kijang
# Processing Record 12 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 5 | tabulbah
# City not found. Skipping...
# Processing Record 14 of Set 5 | avera
# Processing Record 15 of Set 5 | wah
# Processing Record 16 of Set 5 | georgetown
# Processing Record 17 of Set 5 | oussouye
# Processing Record 18 of Set 5 | rafai
# Processing Record 19 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 20 of Set 5 | lushunkou
# City not found. Skipping...
# Processing Record 21 of Set 5 | cortland
# Processing Record 22 of Set 5 | namibe
# Processing Record 23 of Set 5 | hirschaid
# Processing Record 24 of Set 5 | kyren
# Processing Record 25 of Set 5 | arman
# Processing Record 26 of Set 5 | meulaboh
# Processing Record 27 of Set 5 | corowa
# Processing Record 28 of Set 5 | erzin
# Processing Record 29 of Set 5 | cabo san lucas
# Processing Record 30 of Set 5 | nemuro
# Processing Record 31 of Set 5 | san ramon
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | sao jose da coroa grande
# Processing Record 34 of Set 5 | namatanai
# Processing Record 35 of Set 5 | kamaishi
# Processing Record 36 of Set 5 | slave lake
# Processing Record 37 of Set 5 | chengde
# Processing Record 38 of Set 5 | clyde river
# Processing Record 39 of Set 5 | lake havasu city
# Processing Record 40 of Set 5 | santa maria
# Processing Record 41 of Set 5 | jumla
# Processing Record 42 of Set 5 | oswego
# Processing Record 43 of Set 5 | barrow
# Processing Record 44 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 5 | tilichiki
# Processing Record 46 of Set 5 | isangel
# Processing Record 47 of Set 5 | pemangkat
# Processing Record 48 of Set 5 | san cristobal
# Processing Record 49 of Set 5 | portel
# Processing Record 50 of Set 5 | kursumlija
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | dmitriyevka
# Processing Record 3 of Set 6 | pinega
# Processing Record 4 of Set 6 | gorontalo
# Processing Record 5 of Set 6 | chuzhou
# Processing Record 6 of Set 6 | tateyama
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | grigoropolisskaya
# Processing Record 10 of Set 6 | ettlingen
# Processing Record 11 of Set 6 | codrington
# Processing Record 12 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 6 | guadalupe
# Processing Record 14 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 6 | bobonong
# City not found. Skipping...
# Processing Record 16 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 17 of Set 6 | ushtobe
# Processing Record 18 of Set 6 | caceres
# Processing Record 19 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 6 | mackay
# Processing Record 21 of Set 6 | chabahar
# Processing Record 22 of Set 6 | gamba
# Processing Record 23 of Set 6 | souillac
# Processing Record 24 of Set 6 | ahipara
# Processing Record 25 of Set 6 | vielsalm
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | camden
# Processing Record 28 of Set 6 | carnarvon
# Processing Record 29 of Set 6 | vallenar
# Processing Record 30 of Set 6 | burnie
# Processing Record 31 of Set 6 | upernavik
# Processing Record 32 of Set 6 | dhidhdhoo
# Processing Record 33 of Set 6 | saint-joseph
# Processing Record 34 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 6 | filingue
# Processing Record 36 of Set 6 | dubbo
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 39 of Set 6 | xichang
# Processing Record 40 of Set 6 | half moon bay
# Processing Record 41 of Set 6 | coquimbo
# Processing Record 42 of Set 6 | port blair
# Processing Record 43 of Set 6 | chokurdakh
# Processing Record 44 of Set 6 | saryozek
# Processing Record 45 of Set 6 | karla
# Processing Record 46 of Set 6 | virden
# Processing Record 47 of Set 6 | saint-pierre
# Processing Record 48 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 6 | ishigaki
# Processing Record 50 of Set 6 | marsabit
# Processing Record 1 of Set 7 | saint-philippe
# Processing Record 2 of Set 7 | tangshan
# Processing Record 3 of Set 7 | konosha
# Processing Record 4 of Set 7 | kruisfontein
# Processing Record 5 of Set 7 | komatipoort
# Processing Record 6 of Set 7 | play cu
# City not found. Skipping...
# Processing Record 7 of Set 7 | macas
# Processing Record 8 of Set 7 | narsaq
# Processing Record 9 of Set 7 | vestmannaeyjar
# Processing Record 10 of Set 7 | chapais
# Processing Record 11 of Set 7 | gimli
# Processing Record 12 of Set 7 | vila franca do campo
# Processing Record 13 of Set 7 | ketchikan
# Processing Record 14 of Set 7 | magaria
# Processing Record 15 of Set 7 | saint-francois
# Processing Record 16 of Set 7 | pimentel
# Processing Record 17 of Set 7 | zatoka
# Processing Record 18 of Set 7 | kaduna
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | andros town
# Processing Record 21 of Set 7 | tambopata
# Processing Record 22 of Set 7 | paita
# Processing Record 23 of Set 7 | chaman
# Processing Record 24 of Set 7 | talnakh
# Processing Record 25 of Set 7 | rawson
# Processing Record 26 of Set 7 | mizdah
# Processing Record 27 of Set 7 | dalbandin
# Processing Record 28 of Set 7 | almaznyy
# Processing Record 29 of Set 7 | mecca
# Processing Record 30 of Set 7 | capao da canoa
# Processing Record 31 of Set 7 | guadix
# Processing Record 32 of Set 7 | norman wells
# Processing Record 33 of Set 7 | nantucket
# Processing Record 34 of Set 7 | jiangyou
# Processing Record 35 of Set 7 | linxia
# Processing Record 36 of Set 7 | sovetskiy
# Processing Record 37 of Set 7 | plettenberg bay
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | port lincoln
# Processing Record 40 of Set 7 | iquitos
# Processing Record 41 of Set 7 | mahibadhoo
# Processing Record 42 of Set 7 | ann arbor
# Processing Record 43 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 44 of Set 7 | luderitz
# Processing Record 45 of Set 7 | san jose
# Processing Record 46 of Set 7 | naze
# Processing Record 47 of Set 7 | svetlogorsk
# Processing Record 48 of Set 7 | shatki
# Processing Record 49 of Set 7 | pucallpa
# Processing Record 50 of Set 7 | ust-maya
# Processing Record 1 of Set 8 | sijunjung
# Processing Record 2 of Set 8 | oeiras
# Processing Record 3 of Set 8 | aflao
# Processing Record 4 of Set 8 | manavalakurichi
# Processing Record 5 of Set 8 | inuvik
# Processing Record 6 of Set 8 | hay river
# Processing Record 7 of Set 8 | tongliao
# Processing Record 8 of Set 8 | riyadh
# Processing Record 9 of Set 8 | shkotovo-22
# City not found. Skipping...
# Processing Record 10 of Set 8 | villa carlos paz
# Processing Record 11 of Set 8 | cherskiy
# Processing Record 12 of Set 8 | inhumas
# Processing Record 13 of Set 8 | guerrero negro
# Processing Record 14 of Set 8 | macenta
# Processing Record 15 of Set 8 | belorechensk
# Processing Record 16 of Set 8 | dingle
# Processing Record 17 of Set 8 | aconibe
# Processing Record 18 of Set 8 | guane
# Processing Record 19 of Set 8 | camocim
# Processing Record 20 of Set 8 | olhao
# Processing Record 21 of Set 8 | virginia beach
# Processing Record 22 of Set 8 | madras
# Processing Record 23 of Set 8 | tandalti
# Processing Record 24 of Set 8 | los llanos de aridane
# Processing Record 25 of Set 8 | cedar city
# Processing Record 26 of Set 8 | yima
# Processing Record 27 of Set 8 | aklavik
# Processing Record 28 of Set 8 | san patricio
# Processing Record 29 of Set 8 | medicine hat
# Processing Record 30 of Set 8 | dharchula
# Processing Record 31 of Set 8 | tucuman
# Processing Record 32 of Set 8 | balad
# Processing Record 33 of Set 8 | kununurra
# Processing Record 34 of Set 8 | vychegodskiy
# Processing Record 35 of Set 8 | broken hill
# Processing Record 36 of Set 8 | zima
# Processing Record 37 of Set 8 | san felipe
# Processing Record 38 of Set 8 | kemijarvi
# Processing Record 39 of Set 8 | damavand
# Processing Record 40 of Set 8 | la rioja
# Processing Record 41 of Set 8 | bagotville
# Processing Record 42 of Set 8 | esso
# Processing Record 43 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 8 | nyimba
# Processing Record 45 of Set 8 | zboriste
# Processing Record 46 of Set 8 | tukums
# Processing Record 47 of Set 8 | turayf
# Processing Record 48 of Set 8 | moose factory
# Processing Record 49 of Set 8 | zaysan
# Processing Record 50 of Set 8 | benguela
# Processing Record 1 of Set 9 | yeppoon
# Processing Record 2 of Set 9 | hauterive
# Processing Record 3 of Set 9 | huarmey
# Processing Record 4 of Set 9 | zhigansk
# Processing Record 5 of Set 9 | russell
# Processing Record 6 of Set 9 | maningrida
# Processing Record 7 of Set 9 | royan
# Processing Record 8 of Set 9 | chase
# Processing Record 9 of Set 9 | boaco
# Processing Record 10 of Set 9 | ambilobe
# Processing Record 11 of Set 9 | paamiut
# Processing Record 12 of Set 9 | miraflores
# Processing Record 13 of Set 9 | okinawa
# Processing Record 14 of Set 9 | koumac
# Processing Record 15 of Set 9 | assela
# City not found. Skipping...
# Processing Record 16 of Set 9 | victoria
# Processing Record 17 of Set 9 | deputatskiy
# Processing Record 18 of Set 9 | mayo
# Processing Record 19 of Set 9 | chingola
# Processing Record 20 of Set 9 | ilhabela
# Processing Record 21 of Set 9 | bridlington
# Processing Record 22 of Set 9 | barcelona
# Processing Record 23 of Set 9 | agogo
# Processing Record 24 of Set 9 | caravelas
# Processing Record 25 of Set 9 | miri
# Processing Record 26 of Set 9 | tarakan
# Processing Record 27 of Set 9 | vila
# Processing Record 28 of Set 9 | alta floresta
# Processing Record 29 of Set 9 | the valley
# Processing Record 30 of Set 9 | fare
# Processing Record 31 of Set 9 | bandarbeyla
# Processing Record 32 of Set 9 | bhind
# Processing Record 33 of Set 9 | uzunovo
# Processing Record 34 of Set 9 | mugan
# Processing Record 35 of Set 9 | pangai
# Processing Record 36 of Set 9 | santa isabel do rio negro
# Processing Record 37 of Set 9 | rio gallegos
# Processing Record 38 of Set 9 | chuy
# Processing Record 39 of Set 9 | salalah
# Processing Record 40 of Set 9 | payo
# Processing Record 41 of Set 9 | providencia
# Processing Record 42 of Set 9 | milkovo
# Processing Record 43 of Set 9 | ammon
# Processing Record 44 of Set 9 | nurota
# Processing Record 45 of Set 9 | shama
# Processing Record 46 of Set 9 | kota belud
# Processing Record 47 of Set 9 | port-gentil
# Processing Record 48 of Set 9 | parras
# City not found. Skipping...
# Processing Record 49 of Set 9 | hirara
# Processing Record 50 of Set 9 | lachi
# Processing Record 1 of Set 10 | balykshi
# Processing Record 2 of Set 10 | monrovia
# Processing Record 3 of Set 10 | urumqi
# Processing Record 4 of Set 10 | keflavik
# Processing Record 5 of Set 10 | ponta delgada
# Processing Record 6 of Set 10 | barisal
# Processing Record 7 of Set 10 | innisfail
# Processing Record 8 of Set 10 | tiznit
# Processing Record 9 of Set 10 | anaconda
# Processing Record 10 of Set 10 | chernyshevskiy
# Processing Record 11 of Set 10 | rosarito
# Processing Record 12 of Set 10 | saint austell
# Processing Record 13 of Set 10 | karpathos
# Processing Record 14 of Set 10 | pisco
# Processing Record 15 of Set 10 | adre
# Processing Record 16 of Set 10 | shitkino
# Processing Record 17 of Set 10 | yenagoa
# Processing Record 18 of Set 10 | qostanay
# Processing Record 19 of Set 10 | bratsk
# Processing Record 20 of Set 10 | cockburn town
# Processing Record 21 of Set 10 | antalaha
# Processing Record 22 of Set 10 | qarqin
# Processing Record 23 of Set 10 | baruun-urt
# Processing Record 24 of Set 10 | castro-urdiales
# Processing Record 25 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 10 | beloha
# Processing Record 28 of Set 10 | bereda
# Processing Record 29 of Set 10 | vanavara
# Processing Record 30 of Set 10 | moyale
# Processing Record 31 of Set 10 | novikovo
# Processing Record 32 of Set 10 | paonta sahib
# Processing Record 33 of Set 10 | worland
# Processing Record 34 of Set 10 | nome
# Processing Record 35 of Set 10 | albanel
# Processing Record 36 of Set 10 | dunedin
# Processing Record 37 of Set 10 | tambura
# Processing Record 38 of Set 10 | saint-augustin
# Processing Record 39 of Set 10 | zonalnaya stantsiya
# Processing Record 40 of Set 10 | lomovka
# Processing Record 41 of Set 10 | jega
# Processing Record 42 of Set 10 | yinchuan
# Processing Record 43 of Set 10 | alindao
# Processing Record 44 of Set 10 | peruibe
# Processing Record 45 of Set 10 | krasnyy
# Processing Record 46 of Set 10 | ashqelon
# Processing Record 47 of Set 10 | santa vitoria do palmar
# Processing Record 48 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 49 of Set 10 | steamboat springs
# Processing Record 50 of Set 10 | pechenga
# Processing Record 1 of Set 11 | isabela
# Processing Record 2 of Set 11 | mantua
# Processing Record 3 of Set 11 | esperance
# Processing Record 4 of Set 11 | vandra
# Processing Record 5 of Set 11 | amur
# Processing Record 6 of Set 11 | shache
# Processing Record 7 of Set 11 | laguna
# Processing Record 8 of Set 11 | olonets
# Processing Record 9 of Set 11 | luancheng
# Processing Record 10 of Set 11 | onega
# Processing Record 11 of Set 11 | lumsden
# Processing Record 12 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 11 | kutum
# Processing Record 14 of Set 11 | male
# Processing Record 15 of Set 11 | okha
# Processing Record 16 of Set 11 | ponnani
# Processing Record 17 of Set 11 | dombas
# Processing Record 18 of Set 11 | ouegoa
# Processing Record 19 of Set 11 | toul
# Processing Record 20 of Set 11 | mangan
# Processing Record 21 of Set 11 | yulara
# Processing Record 22 of Set 11 | ilulissat
# Processing Record 23 of Set 11 | hualmay
# Processing Record 24 of Set 11 | puerto suarez
# Processing Record 25 of Set 11 | salinopolis
# Processing Record 26 of Set 11 | fairbanks
# Processing Record 27 of Set 11 | san martin
# Processing Record 28 of Set 11 | havoysund
# Processing Record 29 of Set 11 | aradippou
# Processing Record 30 of Set 11 | ozernovskiy
# Processing Record 31 of Set 11 | margate
# Processing Record 32 of Set 11 | sayyan
# Processing Record 33 of Set 11 | roros
# Processing Record 34 of Set 11 | macapa
# Processing Record 35 of Set 11 | dandong
# Processing Record 36 of Set 11 | basoko
# Processing Record 37 of Set 11 | saint anthony
# Processing Record 38 of Set 11 | emerald
# Processing Record 39 of Set 11 | coahuayana
# Processing Record 40 of Set 11 | belmonte
# Processing Record 41 of Set 11 | airai
# Processing Record 42 of Set 11 | durban
# Processing Record 43 of Set 11 | wahpeton
# Processing Record 44 of Set 11 | juan lacaze
# Processing Record 45 of Set 11 | shubarshi
# Processing Record 46 of Set 11 | rundu
# Processing Record 47 of Set 11 | itarema
# Processing Record 48 of Set 11 | san vicente
# Processing Record 49 of Set 11 | shahr-e kord
# Processing Record 50 of Set 11 | shieli
# Processing Record 1 of Set 12 | sabha
# Processing Record 2 of Set 12 | clinton
# Processing Record 3 of Set 12 | tottori
# Processing Record 4 of Set 12 | iskateley
# Processing Record 5 of Set 12 | quang ngai
# Processing Record 6 of Set 12 | atar
# Processing Record 7 of Set 12 | canalete
# Processing Record 8 of Set 12 | mercedes
# Processing Record 9 of Set 12 | boulder city
# Processing Record 10 of Set 12 | reitz
# Processing Record 11 of Set 12 | ziro
# Processing Record 12 of Set 12 | faridpur
# Processing Record 13 of Set 12 | wairoa
# Processing Record 14 of Set 12 | bulaevo
# Processing Record 15 of Set 12 | bolitoc
# Processing Record 16 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 12 | juneau
# Processing Record 18 of Set 12 | bolshaya martynovka
# Processing Record 19 of Set 12 | zyryanka
# Processing Record 20 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 12 | la ronge
# Processing Record 22 of Set 12 | levelland
# Processing Record 23 of Set 12 | zhuhai
# Processing Record 24 of Set 12 | ukiah
# Processing Record 25 of Set 12 | usinsk
# Processing Record 26 of Set 12 | pishin
# Processing Record 27 of Set 12 | zapolyarnyy
# Processing Record 28 of Set 12 | katsuura
# Processing Record 29 of Set 12 | labytnangi
# Processing Record 30 of Set 12 | manoel urbano
# Processing Record 31 of Set 12 | taksimo
# Processing Record 32 of Set 12 | omsukchan
# Processing Record 33 of Set 12 | maragogi
# Processing Record 34 of Set 12 | hami
# Processing Record 35 of Set 12 | iracoubo
# Processing Record 36 of Set 12 | kenai
# Processing Record 37 of Set 12 | soure
# Processing Record 38 of Set 12 | xining
# Processing Record 39 of Set 12 | novyy urengoy
# Processing Record 40 of Set 12 | amapa
# Processing Record 41 of Set 12 | marienburg
# Processing Record 42 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 43 of Set 12 | ihosy
# Processing Record 44 of Set 12 | mount gambier
# Processing Record 45 of Set 12 | cuenca
# Processing Record 46 of Set 12 | liminangcong
# City not found. Skipping...
# Processing Record 47 of Set 12 | saceni
# Processing Record 48 of Set 12 | gijon
# Processing Record 49 of Set 12 | mocuba
# Processing Record 50 of Set 12 | mount pleasant
# Processing Record 1 of Set 13 | flin flon
# Processing Record 2 of Set 13 | talara
# Processing Record 3 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 4 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 13 | kovdor
# Processing Record 6 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 13 | davila
# Processing Record 8 of Set 13 | yuzhno-kurilsk
# Processing Record 9 of Set 13 | san roque
# Processing Record 10 of Set 13 | altoona
# Processing Record 11 of Set 13 | khandbari
# Processing Record 12 of Set 13 | luocheng
# Processing Record 13 of Set 13 | cabedelo
# Processing Record 14 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 13 | datong
# Processing Record 16 of Set 13 | maple creek
# Processing Record 17 of Set 13 | kikwit
# Processing Record 18 of Set 13 | magistralnyy
# Processing Record 19 of Set 13 | lianyuan
# Processing Record 20 of Set 13 | la gaulette
# City not found. Skipping...
# Processing Record 21 of Set 13 | kamogawa
# Processing Record 22 of Set 13 | santiago tuxtla
# Processing Record 23 of Set 13 | kaohsiung
# Processing Record 24 of Set 13 | banda aceh
# Processing Record 25 of Set 13 | sorland
# Processing Record 26 of Set 13 | semirom
# Processing Record 27 of Set 13 | olinda
# Processing Record 28 of Set 13 | huambo
# Processing Record 29 of Set 13 | vuktyl
# Processing Record 30 of Set 13 | nelson bay
# Processing Record 31 of Set 13 | south river
# Processing Record 32 of Set 13 | turukhansk
# Processing Record 33 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 13 | storforshei
# Processing Record 35 of Set 13 | ternate
# Processing Record 36 of Set 13 | niquero
# Processing Record 37 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 13 | abu samrah
# Processing Record 39 of Set 13 | ulladulla
# Processing Record 40 of Set 13 | acapulco
# Processing Record 41 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | corpus christi
# Processing Record 43 of Set 13 | san nicolas
# Processing Record 44 of Set 13 | whitehorse
# Processing Record 45 of Set 13 | ancud
# Processing Record 46 of Set 13 | isiro
# Processing Record 47 of Set 13 | chornukhy
# Processing Record 48 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 13 | teeli
# Processing Record 50 of Set 13 | tuatapere
# Processing Record 1 of Set 14 | port keats
# Processing Record 2 of Set 14 | galich
# Processing Record 3 of Set 14 | askarovo
# Processing Record 4 of Set 14 | vera cruz
# Processing Record 5 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 14 | iskilip
# Processing Record 7 of Set 14 | meadow lake
# Processing Record 8 of Set 14 | dumai
# Processing Record 9 of Set 14 | videira
# Processing Record 10 of Set 14 | lagoa
# Processing Record 11 of Set 14 | daragutan
# Processing Record 12 of Set 14 | talcahuano
# Processing Record 13 of Set 14 | minjur
# Processing Record 14 of Set 14 | lichinga
# Processing Record 15 of Set 14 | yar-sale
# Processing Record 16 of Set 14 | walvis bay
# Processing Record 17 of Set 14 | berlevag
# Processing Record 18 of Set 14 | huzhou
# Processing Record 19 of Set 14 | bafia
# Processing Record 20 of Set 14 | srednekolymsk
# Processing Record 21 of Set 14 | griffith
# Processing Record 22 of Set 14 | bud
# Processing Record 23 of Set 14 | bisira
# Processing Record 24 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 14 | wajir
# Processing Record 26 of Set 14 | hadejia
# Processing Record 27 of Set 14 | cururupu
# Processing Record 28 of Set 14 | ramanuj ganj
# Processing Record 29 of Set 14 | vostok
# Processing Record 30 of Set 14 | strezhevoy
# Processing Record 31 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 14 | kargopol
# Processing Record 33 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 14 | nagato
# Processing Record 35 of Set 14 | shellbrook
# Processing Record 36 of Set 14 | montbrison
# Processing Record 37 of Set 14 | am timan
# Processing Record 38 of Set 14 | storsteinnes
# Processing Record 39 of Set 14 | shingu
# Processing Record 40 of Set 14 | panaba
# Processing Record 41 of Set 14 | kudahuvadhoo
# Processing Record 42 of Set 14 | taoudenni
# Processing Record 43 of Set 14 | jalu
# Processing Record 44 of Set 14 | kasongo-lunda
# Processing Record 45 of Set 14 | san carlos de bariloche
# Processing Record 46 of Set 14 | port macquarie
# Processing Record 47 of Set 14 | agadir
# Processing Record 48 of Set 14 | katangli
# Processing Record 49 of Set 14 | bukachacha
# Processing Record 50 of Set 14 | yumen
# Processing Record 1 of Set 15 | brasilia de minas
# Processing Record 2 of Set 15 | catamarca
# Processing Record 3 of Set 15 | mizan teferi
# Processing Record 4 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 5 of Set 15 | zhangye
# Processing Record 6 of Set 15 | port hedland
# Processing Record 7 of Set 15 | pak chong
# Processing Record 8 of Set 15 | lazaro cardenas
# Processing Record 9 of Set 15 | lethem
# Processing Record 10 of Set 15 | dargaville
# Processing Record 11 of Set 15 | stranraer
# Processing Record 12 of Set 15 | shitanjing
# Processing Record 13 of Set 15 | kadaya
# Processing Record 14 of Set 15 | garm
# City not found. Skipping...
# Processing Record 15 of Set 15 | ngaoundere
# Processing Record 16 of Set 15 | gat
# Processing Record 17 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 15 | husavik
# Processing Record 19 of Set 15 | newark
# Processing Record 20 of Set 15 | zalari
# Processing Record 21 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 15 | wagga wagga
# Processing Record 23 of Set 15 | ewa beach
# Processing Record 24 of Set 15 | smolenka
# Processing Record 25 of Set 15 | kodinsk
# Processing Record 26 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 15 | tingo maria
# Processing Record 28 of Set 15 | fairmont
# Processing Record 29 of Set 15 | hornepayne
# Processing Record 30 of Set 15 | basco
# Processing Record 31 of Set 15 | valparaiso
# Processing Record 32 of Set 15 | inhambane
# Processing Record 33 of Set 15 | umm kaddadah
# Processing Record 34 of Set 15 | charters towers
# Processing Record 35 of Set 15 | lusambo
# Processing Record 36 of Set 15 | karasjok
# Processing Record 37 of Set 15 | muros
# Processing Record 38 of Set 15 | ejea de los caballeros
# Processing Record 39 of Set 15 | san joaquin
# Processing Record 40 of Set 15 | arinos
# Processing Record 41 of Set 15 | douentza
# Processing Record 42 of Set 15 | mirnyy
# Processing Record 43 of Set 15 | yuncheng

# %%
len(city_data)
# Out:
# 681

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bethel      US  41.3712  -73.4140     70.11        93           1
# 1  Severo-Kurilsk      RU  50.6789  156.1250     58.71        95          61
# 2             Vao      NC -22.6667  167.4833     69.31        61          58
# 3         Rikitea      PF -23.1203 -134.9692     72.25        78          79
# 4            Sola      VU -13.8833  167.5500     77.67       100          90
# 5     Yellowknife      CA  62.4560 -114.3525     52.29        84          20
# 6       Busselton      AU -33.6500  115.3333     60.04        78          90
# 7     Kurdzhinovo      RU  43.9884   40.9552     81.79        53           1
# 8        Thompson      CA  55.7435  -97.8558     33.96        93          20
# 9      Port Hardy      CA  50.6996 -127.4199     56.82        95          53
#
#    Wind Speed Current Description
# 0        0.00           clear sky
# 1        5.64       broken clouds
# 2       15.95       broken clouds
# 3       12.64          light rain
# 4        0.00     overcast clouds
# 5        5.75          few clouds
# 6       26.13     overcast clouds
# 7        6.98           clear sky
# 8        2.30          few clouds
# 9        2.98       broken clouds

# %%
#Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
#Export the City_Data into a csv.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
